# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from datetime import time
from datetime import datetime
from datetime import timedelta

plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 12

# %%
df_voltage = pd.read_excel('./article/DATA.xlsx', sheet_name="Sheet2")
df_voltage.Time = pd.to_datetime(df_voltage.Time, format='%H:%M:%S')
df_voltage.Time = (df_voltage.Time - df_voltage.Time[0]).dt.total_seconds() / 60

print(df_voltage.info())
df_voltage
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 951 entries, 0 to 950
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Time     951 non-null    float64
#  1   Voltage  951 non-null    float64
# dtypes: float64(2)
# memory usage: 15.0 KB
# None
#       Time    Voltage
# 0      0.0  51.900002
# 1      0.5  51.900002
# 2      1.0  51.900002
# 3      1.5  51.900002
# 4      2.0  51.900002
# ..     ...        ...
# 946  473.0  33.599998
# 947  473.5  33.599998
# 948  474.0  33.599998
# 949  474.5  33.700001
# 950  475.0  33.700001
#
# [951 rows x 2 columns]

# %%
# plot search of the optimal parameter n_components of PCA
plt.figure(figsize=(16, 3))
plt.subplot(1, 2, 2)

plt.plot(df_voltage.Time, df_voltage.Voltage, '#008bfb') # , label='voltage')
plt.xlabel('Время, мин')
plt.xlim(0, 500)
plt.ylabel('Напряжение, В')
plt.ylim(30, 55)
#plt.legend('Напряжение')
#plt.title('Выходная электрическая характеристика ТОТЭ')

plt.annotate('Работа под нагрузкой', xy=(225, 39.5), 
             xycoords='data', xytext=(120, 33), 
             textcoords='data', fontsize=12, 
             arrowprops=dict(arrowstyle='-|>'))

plt.annotate('', xy=(340, 33), 
             xycoords='data', xytext=(230, 33.3), 
             textcoords='data', fontsize=12, 
             arrowprops=dict(arrowstyle='-|>'))

plt.annotate('Работа от аккумулятора', xy=(100, 52), 
             xycoords='data', xytext=(25, 45), 
             textcoords='data', fontsize=12, 
             arrowprops=dict(arrowstyle='-|>'))

plt.annotate('', xy=(400, 52), 
             xycoords='data', xytext=(140, 45.5), 
             textcoords='data', fontsize=12, 
             arrowprops=dict(arrowstyle='-|>'))

plt.tight_layout()
plt.savefig('pictures/The SOFC system output electrical characteristics.png', dpi = 300, transparent = True)
plt.show()
